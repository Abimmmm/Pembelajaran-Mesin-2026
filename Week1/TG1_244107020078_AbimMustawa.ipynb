# %%
# %pip install PyPREP
# %pip install Scipy
# %pip install wandb
# %pip install scikit-learn
# %pip install pyECG --no-deps
# Out:
# ...
#    ---------------------------------------- 0.0/7.5 MB ? eta -:--:--
#    - -------------------------------------- 0.3/7.5 MB ? eta -:--:--
#    --------- ------------------------------ 1.8/7.5 MB 6.6 MB/s eta 0:00:01
#    ---------------- ----------------------- 3.1/7.5 MB 6.5 MB/s eta 0:00:01
#    ------------------------- -------------- 4.7/7.5 MB 6.9 MB/s eta 0:00:01
#    ------------------------------------ --- 6.8/7.5 MB 7.6 MB/s eta 0:00:01
#    ---------------------------------------- 7.5/7.5 MB 7.7 MB/s  0:00:01
# ...
#
#    ---------------------------------------- 0/3 [pooch]
#    ---------------------------------------- 0/3 [pooch]
#    ---------------------------------------- 0/3 [pooch]
#    ------------- -------------------------- 1/3 [mne]
#    ------------- -------------------------- 1/3 [mne]
#    ------------- -------------------------- 1/3 [mne]
#    ------------- -------------------------- 1/3 [mne]
#    ------------- -------------------------- 1/3 [mne]
# ...
