# %% [markdown]
# Bagian 2
#
# 1. Berikan contoh tentang tidakan melanggar etika dan hukum tentang penggunaan kecerdasan buatan. Sertakan referensi yang digunakan.
#
# Jawab :
# Salah satu bentuk penyalahgunaan AI yang paling mencolok di Indonesia adalah penggunaan teknologi deepfake, yakni teknologi yang memanfaatkan AI untuk menciptakan konten visual atau audio palsu yang sangat menyerupai kenyataan (Budiman, 2019). Deepfake kerap digunakan untuk menyebarkan konten pornografi nonkonsensual, menjatuhkan reputasi tokoh publik, atau menyebarkan informasi palsu yang dapat memengaruhi opini publik. Contoh kasus yang cukup meresahkan adalah beredarnya video deepfake yang menampilkan tokoh-tokoh politik dengan pernyataan palsu, yang disebarkan menjelang masa kampanye pemilu.
# SUMBER : https://joecy.org/index.php/joecy/article/view/4647
#
# 2. Berikan contoh tentang dampak energi dan lingkungan terhadap pemanfaatan kecerdasan buatan dan bagaimana cara mengatasinya (Anda dapat memberikan pendapat pribadi). Sertakan referensi yang digunakan.
#
# Jawab :
# Dampak lingkungan dari kecerdasan buatan mencakup konsumsi listrik yang digunakan untuk pelatihan dan penggunaan model pemelajaran dalam, serta jejak karbon dan penggunaan air untuk kepentingan terkait.
# SUMBER : [https://id.wikipedia.org/wiki/Dampak_lingkungan_dari_kecerdasan_buatan]

# %% [markdown]
# Bagian 1
#
# Jelaskan Kegunaan masing masing library tersebut
# 1. PyPREP : library untuk mengimplementasikan algoritma PREP (Preprocessing Pipeline) pada data EEG
# 2. Scipy : library yang menyediakan fungsi-fungsi matematika dan statistik tingkat lanjut. seperti aljabar linear, statistik, interpolasi
# Pengolahan sinyal dan gambar
# 3. wandb : library berfungsi untuk mencatat metrik training secara real-time, visualisasi grafik training, membandingkan berbagai model, menyimpan versi model, hyperparameter, dan konfigurasi
# 4. pyECG : library untuk membaca, memproses, dan menganalisis sinyal ECG sinyal jantung

# %%
# %pip install mne
# %pip install PyPREP
# %pip install Scipy
# %pip install wandb
# %pip install scikit-learn
# %pip install pyECG --no-deps
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
